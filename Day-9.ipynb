# %% [markdown]
# <h1 style="background: linear-gradient(160deg, #fff5f9 0%, #ffe8f3 50%, #ffd6ec 100%); border: 1.5px solid #ffcce8; border-radius: 16px; padding: 22px 32px; font-family: 'Trebuchet MS', sans-serif; max-width: 320px; margin: 0 auto; box-shadow: 0 4px 20px rgba(255,105,180,0.15), inset 0 1px 0 rgba(255,255,255,1); text-align: center; color: #f72585; font-size: 26px; font-weight: 900; line-height: 1.8;">
#
#   <span style="font-size: 10px; letter-spacing: 0.28em; text-transform: uppercase; color: #e06090; background: white; border: 1px solid #ffb8d9; padding: 3px 13px; border-radius: 99px; display: block; width: fit-content; margin: 0 auto 14px; font-weight: 400;">✦ LeetCode #387 · Easy ✦</span>
#
#   First Unique Character in String
#
#
#   <span style="display: block; width: 70%; height: 1px; background: linear-gradient(90deg, transparent, #ffb8d9, transparent); margin: 12px auto;"></span>
#
#   <span style="font-size: 13px; display: block; font-weight: 400; color: #f093b0; letter-spacing: 3px;">(=^･ω･^=) ✦ (=^･ω･^=)</span>
#
# </h1>

# %%
class Solution(object):
    def firstUniqChar(self, s):
        for i, j in enumerate(s): # I is the index value and j means the unique characters
            if s.count(j) == 1:   # If count of character is one 
                return i          # Return index of character  
        return -1                 # If no unique charater exist

# %%
s = "loveleetcode"
sol = Solution()
print(sol.firstUniqChar(s))
# Out:
# 2
